# %% [markdown]
# ## Способы нахождения упоминаний товаров в продуктах.

# %% [markdown]
# 1. Самый "топорный" и простой - составить словарь из данных наазваний продуктов. Кажется, что он покрывает достаточно много, однако, должен еще и вытаскивать ненужные вещи типа прилагательных и коллокаций из раздела "первый на рынке".
# 1.1 Здесь еще можно попробовать собрать словарь из самих отзывов с помощью bootstrapping - если мы увидим, что ревью похожи друг на друга по формулам.
# 2. Rule-based подход - парсер типа natasha неплохо подходит для задачи, если мы знаем, что названия продуктов "похожи" на именованные сущности. Так как наш датасет тематичен, можно предполоожить, что это будет хорошо.
# 3. Machine learning-based подход - например, применение CRF к датасету с pos-тэгами и другими характеристикмаи (например, капитализация). Звучит здорово, но требует предварительной ручной работы.

# %%
import pandas as pd

df = pd.read_json('/Users/kseniadudiy/Downloads/Magazine_Subscriptions.json', lines=True)

# %%
reviews = df['reviewText']
reviews
# Out:
# 0        for computer enthusiast, MaxPC is a welcome si...
# 1        Thank god this is not a Ziff Davis publication...
# 2        Antiques Magazine is a publication made for an...
# 3        This beautiful magazine is in itself a work of...
# 4                                A great read every issue.
#                                ...
# 89684    This was a nice surprise for my boyfriend. He ...
# 89685    Magazine looks like it is printed on recycled ...
# 89686    cant go wrong with an SI subscription\nvery pl...
# 89687    This magazine is by far my all time favorite o...
# 89688               Nice magazine. Good info and articles.
# Name: reviewText, Length: 89689, dtype: object

# %% [markdown]
# Пробуем собрать словарь по шаблонаам с помощью bootstrapping.

# %% [markdown]
# Понимаем, что у нас большая часть именованных сущностей связана с журналами и их публикацией. Препроцессим текст так, чтобы на выходе мы получили списки со встроенными словарями, потом итерируемся по ним по шаблону.
#
# Так как наша область крайне мала, мы знаем, что в наш словарь мы можем вручную добавить максимально употребимые слова: magazine, journal, publication.
#
# X - наша именованная сущность (т.е. название журнала). У X должны быть следующие характеристики (некоторые из которых обязательны):
#
# 1. Заглавная буква в начале (понятно, что некоторые, как я, например, любят писать вообще без заглавных букв, но мы это опустим) - обязательно.
# 2. Слово "magazine" после.
# 3. Грамматические характеристики: noun/adj.
# 4. Глагол после.
# 5. Слова в начале предложения не анализируются - опять же, сложно ожидать от пишущих отзывы максимальной грамматичности, однако, сама именованная сущность по правилам не может находиться в первой позиции, ее обязательно предваряет артикль - это правило кажется максимально общеупотребимым, поэтому мы позволим себе на него опереться.

# %%
from nltk import pos_tag
def get_lists(x):
    l1 = x.split(' ')
    l2 = []
    if len(l1) > 1:
        a = pos_tag(l1)
        for item in a:
            dic = {}
            dic['word'] = item[0]
            if item[0][0].isupper():
                dic['letter'] = 'U'
            else:
                dic['letter'] = 'L'
            if len(item) > 1:
                dic['pos'] = item[1]
            else:
                dic['pos'] = 'None'
            l2.append(dic)
    return(l2)

# %%
print(get_lists('An rat ate my f'))
# Out:
# [{'word': 'An', 'letter': 'U', 'pos': 'DT'}, {'word': 'rat', 'letter': 'L', 'pos': 'NN'}, {'word': 'ate', 'letter': 'L', 'pos': 'NN'}, {'word': 'my', 'letter': 'L', 'pos': 'PRP$'}, {'word': 'f', 'letter': 'L', 'pos': 'NN'}]

# %%
#чистим текст и сразу превращаем в нужные нам списки
import re
f = []
for el in reviews:
    d = re.findall("[\w']+|[.,!?;]", str(el))
    for item in d:
        if re.match('[.,?!;:-]', item) != None:
            d.remove(item)
        else:
            pass
    new = ' '.join(d)
    f.append(new)

# %%
fin = []
for item in f:
    fin.append(get_lists(item))
print(fin[:10])
# Out:
# [[{'word': 'for', 'letter': 'L', 'pos': 'IN'}, {'word': 'computer', 'letter': 'L', 'pos': 'NN'}, {'word': 'enthusiast', 'letter': 'L', 'pos': 'NN'}, {'word': 'MaxPC', 'letter': 'U', 'pos': 'NNP'}, {'word': 'is', 'letter': 'L', 'pos': 'VBZ'}, {'word': 'a', 'letter': 'L', 'pos': 'DT'}, {'word': 'welcome', 'letter': 'L', 'pos': 'JJ'}, {'word': 'sight', 'letter': 'L', 'pos': 'NN'}, {'word': 'in', 'letter': 'L', 'pos': 'IN'}, {'word': 'your', 'letter': 'L', 'pos': 'PRP$'}, {'word': 'mailbox', 'letter': 'L', 'pos': 'NN'}, {'word': 'i', 'letter': 'L', 'pos': 'NN'}, {'word': 'can', 'letter': 'L', 'pos': 'MD'}, {'word': 'remember', 'letter': 'L', 'pos': 'VB'}, {'word': 'for', 'letter': 'L', 'pos': 'IN'}, {'word': 'years', 'letter': 'L', 'pos': 'NNS'}, {'word': 'savorying', 'letter': 'L', 'pos': 'VBG'}, {'word': 'every', 'letter': 'L', 'pos': 'DT'}, {'word': 'page', 'letter': 'L', 'pos': 'NN'}, {'word': 'of', 'letter': 'L', 'pos': 'IN'}, {'word': 'boot', 'letter': 'L', 'pos': 'NN'}, {'word': 'as', 'letter': 'L', 'pos': 'IN'}, {'word': 'it', 'letter': 'L', 'pos': 'PRP'}, {'word': 'was', 'letter': 'L', 'pos': 'VBD'}, {'word': 'called', 'letter': 'L', 'pos': 'VBN'}, {'word': 'in', 'letter': 'L', 'pos': 'IN'}, {'word': 'beginning', 'letter': 'L', 'pos': 'VBG'}, {'word': 'as', 'letter': 'L', 'pos': 'IN'}, {'word': 'i', 'letter': 'L', 'pos': 'NN'}, {'word': 'was', 'letter': 'L', 'pos': 'VBD'}, {'word': 'and', 'letter': 'L', 'pos': 'CC'}, {'word': 'still', 'letter': 'L', 'pos': 'RB'}, {'word': 'am', 'letter': 'L', 'pos': 'VBP'}, {'word': 'obcessed', 'letter': 'L', 'pos': 'VBN'}, {'word': 'with', 'letter': 'L', 'pos': 'IN'}, {'word': "PC's", 'letter': 'U', 'pos': 'NNP'}, {'word': 'Anyone', 'letter': 'U', 'pos': 'NNP'}, {'word': 'from', 'letter': 'L', 'pos': 'IN'}, {'word': 'advanced', 'letter': 'L', 'pos': 'JJ'}, {'word': 'users', 'letter': 'L', 'pos': 'NNS'}, {'word': 'to', 'letter': 'L', 'pos': 'TO'}, {'word': 'beginners', 'letter': 'L', 'pos': 'NNS'}, {'word': 'looking', 'letter': 'L', 'pos': 'VBG'}, {'word': 'for', 'letter': 'L', 'pos': 'IN'}, {'word': 'knowledge', 'letter': 'L', 'pos': 'NN'}, {'word': 'can', 'letter': 'L', 'pos': 'MD'}, {'word': 'profit', 'letter': 'L', 'pos': 'VB'}, {'word': 'from', 'letter': 'L', 'pos': 'IN'}, {'word': 'every', 'letter': 'L', 'pos': 'DT'}, {'word': 'issue', 'letter': 'L', 'pos': 'NN'}, {'word': 'of', 'letter': 'L', 'pos': 'IN'}, {'word': 'MaxPC', 'letter': 'U', 'pos': 'NNP'}, {'word': 'the', 'letter': 'L', 'pos': 'DT'}, {'word': 'icing', 'letter': 'L', 'pos': 'NN'}, {'word': 'on', 'letter': 'L', 'pos': 'IN'}, {'word': 'the', 'letter': 'L', 'pos': 'DT'}, {'word': 'cake', 'letter': 'L', 'pos': 'NN'}, {'word': 'is', 'letter': 'L', 'pos': 'VBZ'}, {'word': 'the', 'letter': 'L', 'pos': 'DT'}, {'word': 'subscription', 'letter': 'L', 'pos': 'NN'}, {'word': 'that', 'letter': 'L', 'pos': 'WDT'}, {'word': 'comes', 'letter': 'L', 'pos': 'VBZ'}, {'word': 'with', 'letter': 'L', 'pos': 'IN'}, {'word': 'a', 'letter': 'L', 'pos': 'DT'}, {'word': 'CD', 'letter': 'U', 'pos': 'NN'}, {'word': 'ROM', 'letter': 'U', 'pos': 'NNP'}, {'word': 'as', 'letter': 'L', 'pos': 'IN'}, {'word': 'it', 'letter': 'L', 'pos': 'PRP'}, {'word': 'is', 'letter': 'L', 'pos': 'VBZ'}, {'word': 'packed', 'letter': 'L', 'pos': 'VBN'}, {'word': 'with', 'letter': 'L', 'pos': 'IN'}, {'word': 'demos', 'letter': 'L', 'pos': 'JJ'}, {'word': 'utilities', 'letter': 'L', 'pos': 'NNS'}, {'word': 'and', 'letter': 'L', 'pos': 'CC'}, {'word': 'other', 'letter': 'L', 'pos': 'JJ'}, {'word': 'useful', 'letter': 'L', 'pos': 'JJ'}, {'word': 'apps', 'letter': 'L', 'pos': 'JJ'}, {'word': 'very', 'letter': 'L', 'pos': 'RB'}, {'word': 'helpful', 'letter': 'L', 'pos': 'JJ'}, {'word': 'for', 'letter': 'L', 'pos': 'IN'}, {'word': 'those', 'letter': 'L', 'pos': 'DT'}, {'word': 'not', 'letter': 'L', 'pos': 'RB'}, {'word': 'blessed', 'letter': 'L', 'pos': 'VBN'}, {'word': 'with', 'letter': 'L', 'pos': 'IN'}, {'word': 'broadband', 'letter': 'L', 'pos': 'NN'}, {'word': 'connection ...

# %%
from nltk.corpus import stopwords
words = ['magazine', 'journal', 'publication']
first = ['NN', 'NNP', 'NNS', 'JJ', 'JJR', 'JJS']
stops = list(stopwords.words('english'))
for item in fin:
    for element in item:
        i = item.index(element)
        if i > 0:
            if element['letter'] == 'U':
                if element['word'].lower() not in stops:
                    if element['pos'] in first:
                        if i < len(item)-1:
                            a = item[i+1]
                            if a['letter'] == 'U':
                                if element['word'].lower() not in stops:
                                    l = []
                                    l.append(element['word'])
                                    l.append(a['word'])
                                    words.append(' '.join(l))
                                else:
                                    words.append(element['word'])
                        else:
                            words.append(element['word'])
print(words)
# Out:
# ['magazine', 'journal', 'publication', "PC's Anyone", 'CD ROM', 'CD ROM', 'Ziff Davis', 'Driver Technical', 'Eating Utensil', 'Utensil Collection', 'Collection Spanish', 'Spanish Culture', 'Overall Antiques', 'Maximum PC', 'PC MPC', 'Period As', 'Maximum PC', 'Maximum PC', 'Maximum PC', 'Foreign Affairs', 'PC Always', 'Future US', 'US Customer', 'Customer Service', 'Maximum PC', 'Best PC', 'Maximun PC', 'PC The', 'PC World', 'World Maximum', 'Maximum PC', 'PC World', 'PC World', 'World Maximum', 'Maximum PC', 'PC World', 'Maximum PC', 'PC The', 'Windows This', 'PC Accelerator', 'Accelerator God', 'God Bless', 'PC Accelerator', 'Great PC', 'PC Accelerator', "PC'er", 'Maximum PC', 'New England', 'England Colonial', 'Colonial This', 'Ask Handyman', 'Handyman Here', 'Workshop Tips', 'Tips In', 'Handy Hints', 'Hints More', 'Great Goofs', 'Goofs Funny', 'New England', 'Products Section', 'Section These', 'Family Handyman', 'Todays Homeowner', 'Old House', 'Family Handyman', 'Handyman For', 'Family Handyman', 'Handiman A', 'Maximum PC', 'PC The', 'Maximum PC', 'PC The', 'PC The', 'Computer Shopper', 'Maximum PC', 'Maximum PC', 'Max PC', 'Thanks Amazon', 'PC MAGAZINE', 'MAGAZINE Pretty', 'WOW Thank', 'Thank God', 'God I', 'HPs Great', 'Software Head', 'Bryan', 'Maximum PC', "Amazon I've", 'CD DVD', 'ALLURE It', 'Kevyn Aucoin', 'ALLURE It', 'ALLURE It', 'Garren Bobbi', 'Bobbi Brown', 'Sally Herschberger', 'Herschberger And', 'FABULOUS Kevyn', 'Kevyn Aucoin', 'Mat Dillon', 'Mark Wahlberg', 'Know Tell', 'Colin Farrell', "GQ There's", 'Details Even', 'Details Even', 'Details Even', 'Details Even', 'Vogue I', 'BS So', 'Sandy Bridge', 'Update The', 'Maximum PC', 'Maximum PC', 'Maximum PC', 'Maximum PC', 'Maximum PC', 'PC Mag', 'PS No', 'Maximum PC', 'Subscription Manager', 'AUTO RENEWAL', 'RENEWAL Read', 'Amazon Future', 'Amazon Future', 'CD', 'Maximum PC', "Maximum PC's", "Intel's Sandy", 'Sandy Bridge', 'Sandy Bridge', 'Great TV', 'Maximum PC', 'CD I', 'MaximumPC', 'Stuff', 'Allure I', 'Linda Wells', 'Wells Allure', 'Allure I', 'Allure I', 'Linda Wells', 'Linda Wells', 'Ladies Home', 'Home Journal', 'Dream Machine', 'Machine PC', 'PC Magazine', 'Doctor This', 'News Presents', 'Reviews Here', 'Overall I', 'Maximum PC', 'Maximum PC', 'Maximum PC', 'Maximum PC', 'Maximum PC', 'Smart Computing', 'Family Handyman', 'Best Reviewed', 'Reviewed Lawn', 'Lawn Care', 'Care Products', 'Fakespot Review', 'Review Analysis', 'Family Handyman', 'Handyman If', "Amazon Don't", 'GQ Alot', 'Articles Interviews', 'Bass Players', 'Magazine Stanley', 'Stanley Clarke', 'Interviews I', 'Marcus Miller', 'James Jamerson', 'Larry Graham', 'Graham Verdine', 'Verdine White', 'White John', 'John Patitucci', 'Patitucci Louis', 'Louis Johnson', 'Johnson Flea', 'Flea Bootsy', 'Bootsy Collins', 'Collins Charles', 'Charles Mingus', 'Bass Player', 'CD ROMs', 'Yah I', 'CD ROMs', 'CD ROMs', 'WAIT A', 'MINUTE HERE', 'B S', 'Oct Nov', 'CPU Is', 'Maximum PC', 'Maximum PC', 'Brent', 'Maximum PC', 'Maximum PC', 'Mario Zanocchi', 'Zanocchi', 'Jim', 'NOTHING Im', 'Kudos', 'New Yorker', 'Yorker Unfortunately', 'Unfortunately Details', 'Maximum PC', 'Maximum PC', 'Maximum PC', 'FYI I', 'Maximum PC', 'PC Magazine', 'YEARS I', 'Tech Magazines', 'Maximum PC', 'PRINT ONLY', "CD's Upon", 'Maximum PC', 'MAGAZINE I', 'COULD HAVE', 'DOWNLOADED THE', "FREE PDF'S", "PDF'S THAT", 'MAXIMUM PC', 'PC Magazine', 'MAKES AVAILABLE', 'AVAILABLE ON', 'WEBSITE I', 'BTW AMAZON', 'AMAZON CUSTOMER', 'CUSTOMER SERVICE', 'SERVICE REFUSES', 'REFUSES TO', 'CANCEL THE', 'SUBSCRIPTION OUTRIGHT', 'OUTRIGHT DO', 'BETTER OFF', 'DIRECT FROM', 'MAXIMUM PC', 'PC World', 'World Magazine', 'Magazine They', 'Discs I', 'Al Gore', 'ResistTheMedia', 'Regardless I', 'Black Friday', 'Details I', 'Holidays Within', 'West Coast', 'Coast', 'Details', 'Tree', 'FHM It', 'Consequently I', 'Help', 'QVC No', 'Disappointing', 'DIYer I', 'Mag Very', 'PC MAG', 'MAG AT', 'PRESENT IT', 'EVERYTHING I', 'INTERESTED IN', 'NEW PRODUCTS', 'PRODU ...

# %% [markdown]
# Отлично, что-то получилось! Давайте посчитаем повторяющиеся элементы - именно они и будут названиями.

# %%
from collections import Counter

cnt = Counter
imp = [key for key, _ in cnt.most_common(50)]
# Out:
# [('Kindle Fire', 1012),
#  ('New Yorker', 847),
#  ('National Geographic', 762),
#  ("Reader's Digest", 416),
#  ('Kindle I', 326),
#  ('Amazon I', 323),
#  ('TV Guide', 306),
#  ('New York', 301),
#  ('Popular Science', 270),
#  ('Southern Living', 258),
#  ('U S', 249),
#  ('Food Network', 243),
#  ('Magazine', 241),
#  ('Amazon', 232),
#  ('Good Housekeeping', 232),
#  ('Vanity Fair', 230),
#  ('Scientific American', 223),
#  ('Real Simple', 219),
#  ('Entertainment Weekly', 219),
#  ('Thanks', 215),
#  ('Marie Claire', 206),
#  ('Popular Mechanics', 186),
#  ('US Weekly', 173),
#  ('Consumer Reports', 156),
#  ("Men's Health", 151),
#  ('Bon Appetit', 148),
#  ('Country Living', 145),
#  ('Martha Stewart', 145),
#  ('Kindle', 142),
#  ('Magazine I', 137),
#  ('Conde Nast', 130),
#  ('Readers Digest', 128),
#  ('Better Homes', 121),
#  ('Sports Illustrated', 118),
#  ('Fire HD', 117),
#  ('Fire I', 115),
#  ('United States', 110),
#  ('Family Handyman', 109),
#  ('Golf Digest', 101),
#  ('Cooking Light', 99),
#  ('Old House', 95),
#  ('Science Fiction', 95),
#  ('Nat Geo', 95),
#  ('American Girl', 93),
#  ("Woman's Day", 91),
#  ('Maximum PC', 87),
#  ('Family Circle', 86),
#  ('Mental Floss', 83),
#  ('Rachael Ray', 83),
#  ('Amazon The', 82)]

# %% [markdown]
# Похоже на правду. Конечно, попали ненужные элементы, но их не так много.

# %% [markdown]
# ## Собираю n-граммы

# %%
#чистим корпус

alte = ' '.join(f)
wrds = alte.split(' ')
for item in wrds:
    i = wrds.index(item)
    if item in stops:
        wrds.pop(i)

print(wrds)

# %%
neue = []
for item in wrds:
    neue.append(item.lower)

corpus_len = len(neue)
freq = cnt(neue)

clean_text = ' '.join(neue)

# %%
colls = []
n = 0
for c in clean_text:
    for item in imp:
        found = re.findall(item, c)
        if found:
            n += 1
        for f in found:
            collocations.append((f[0], f[1]))
            collocations.append((f[1], f[2]))

# %%
cnt(collocations).most_common(50)

# %% [markdown]
# ## Метрики
